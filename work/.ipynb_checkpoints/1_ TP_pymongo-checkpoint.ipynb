# %% [markdown]
# # Mongodb

# %% [markdown]
# Dans ce TP nous allons utiliser la librairie pymongo, pour créer une base de données dans mongodb avec python puis la questionner.

# %% [markdown]
# ### Data
# Voici des données au format csv, elles sont une partie d'un dataset recensant les crimes au Etats-Unis entre 1984 et 2014.
#
# https://drive.google.com/file/d/10z7kUXDO4BHffJ6ZfVc42CgIs5558vGd/view?usp=sharing

# %% [markdown]
# ### Création de la BDD

# %%
from pymongo import MongoClient
import json
import streamlit as st
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# Créez une fonction python pour passer ce csv dans une base de données mongo, chaque lignes devra être un document.

# %% [markdown]
# ### Requêter la BDD

# %% [markdown]
# Créez un connecteur pour votre BDD

# %%
client = MongoClient(
    'mongo',
    port=27017,
    username='root',
    password='root',
    authMechanism='SCRAM-SHA-256'
)
db = client.spotify
table = db.documents

# %%
# Lecture du csv
df = spark.read.format('csv').options(header=True).load('data/Spotify/genres_v2.csv')
df.dtypes
# Out:
# [('danceability', 'double'),
#  ('energy', 'double'),
#  ('key', 'int'),
#  ('loudness', 'double'),
#  ('mode', 'int'),
#  ('speechiness', 'double'),
#  ('acousticness', 'double'),
#  ('instrumentalness', 'double'),
#  ('liveness', 'double'),
#  ('valence', 'double'),
#  ('tempo', 'double'),
#  ('type', 'string'),
#  ('id', 'string'),
#  ('uri', 'string'),
#  ('track_href', 'string'),
#  ('analysis_url', 'string'),
#  ('duration_ms', 'int'),
#  ('time_signature', 'int'),
#  ('genre', 'string'),
#  ('song_name', 'string'),
#  ('Unnamed: 0', 'string'),
#  ('title', 'string')]

# %%
# Ecriture dans le HDFS
df.write.csv("hdfs://hadoop-master:9000/spotify.csv")

# %%
# Lecture dans le HDFS

# %%
# En une seule fois
if table.count_documents({}) == 0:    
    records = df.toPandas().to_dict(orient='records')
    table.insert_many(records)
    
df.toPandas()
# Out:
# [{'danceability': '0.831',
#   'energy': '0.8140000000000001',
#   'key': '2',
#   'loudness': '-7.364',
#   'mode': '1',
#   'speechiness': '0.42',
#   'acousticness': '0.0598',
#   'instrumentalness': '0.0134',
#   'liveness': '0.0556',
#   'valence': '0.389',
#   'tempo': '156.985',
#   'type': 'audio_features',
#   'id': '2Vc6NJ9PW9gD9q343XFRKx',
#   'uri': 'spotify:track:2Vc6NJ9PW9gD9q343XFRKx',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD9q343XFRKx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Vc6NJ9PW9gD9q343XFRKx',
#   'duration_ms': '124539',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Mercury: Retrograde',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f13c')},
#  {'danceability': '0.7190000000000001',
#   'energy': '0.493',
#   'key': '8',
#   'loudness': '-7.23',
#   'mode': '1',
#   'speechiness': '0.0794',
#   'acousticness': '0.401',
#   'instrumentalness': '0.0',
#   'liveness': '0.11800000000000001',
#   'valence': '0.124',
#   'tempo': '115.08',
#   'type': 'audio_features',
#   'id': '7pgJBLVz5VmnL7uGHmRj6p',
#   'uri': 'spotify:track:7pgJBLVz5VmnL7uGHmRj6p',
#   'track_href': 'https://api.spotify.com/v1/tracks/7pgJBLVz5VmnL7uGHmRj6p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7pgJBLVz5VmnL7uGHmRj6p',
#   'duration_ms': '224427',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Pathology',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f13d')},
#  {'danceability': '0.85',
#   'energy': '0.893',
#   'key': '5',
#   'loudness': '-4.783',
#   'mode': '1',
#   'speechiness': '0.0623',
#   'acousticness': '0.0138',
#   'instrumentalness': '4.14e-06',
#   'liveness': '0.37200000000000005',
#   'valence': '0.0391',
#   'tempo': '218.05',
#   'type': 'audio_features',
#   'id': '0vSWgAlfpye0WCGeNmuNhy',
#   'uri': 'spotify:track:0vSWgAlfpye0WCGeNmuNhy',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vSWgAlfpye0WCGeNmuNhy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vSWgAlfpye0WCGeNmuNhy',
#   'duration_ms': '98821',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Symbiote',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f13e')},
#  {'danceability': '0.47600000000000003',
#   'energy': '0.7809999999999999',
#   'key': '0',
#   'loudness': '-4.71',
#   'mode': '1',
#   'speechiness': '0.10300000000000001',
#   'acousticness': '0.0237',
#   'instrumentalness': '0.0',
#   'liveness': '0.114',
#   'valence': '0.175',
#   'tempo': '186.94799999999998',
#   'type': 'audio_features',
#   'id': '0VSXnJqQkwuH2ei1nOQ1nu',
#   'uri': 'spotify:track:0VSXnJqQkwuH2ei1nOQ1nu',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VSXnJqQkwuH2ei1nOQ1nu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VSXnJqQkwuH2ei1nOQ1nu',
#   'duration_ms': '123661',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'ProductOfDrugs (Prod. The Virus and Antidote)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f13f')},
#  {'danceability': '0.7979999999999999',
#   'energy': '0.624',
#   'key': '2',
#   'loudness': '-7.667999999999999',
#   'mode': '1',
#   'speechiness': '0.293',
#   'acousticness': '0.217',
#   'instrumentalness': '0.0',
#   'liveness': '0.166',
#   'valence': '0.591',
#   'tempo': '147.988',
#   'type': 'audio_features',
#   'id': '4jCeguq9rMTlbMmPHuO7S3',
#   'uri': 'spotify:track:4jCeguq9rMTlbMmPHuO7S3',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jCeguq9rMTlbMmPHuO7S3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jCeguq9rMTlbMmPHuO7S3',
#   'duration_ms': '123298',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Venom',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f140')},
#  {'danceability': '0.721',
#   'energy': '0.568',
#   'key': '0',
#   'loudness': '-11.295',
#   'mode': '1',
#   'speechiness': '0.414',
#   'acousticness': '0.0452',
#   'instrumentalness': '0.212',
#   'liveness': '0.128',
#   'valence': '0.109',
#   'tempo': '144.915',
#   'type': 'audio_features',
#   'id': '6fsypiJHyWmeINsOLC1cos',
#   'uri': 'spotify:track:6fsypiJHyWmeINsOLC1cos',
#   'track_href': 'https://api.spotify.com/v1/tracks/6fsypiJHyWmeINsOLC1cos',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6fsypiJHyWmeINsOLC1cos',
#   'duration_ms': '112511',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Gatteka',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f141')},
#  {'danceability': '0.718',
#   'energy': '0.6679999999999999',
#   'key': '8',
#   'loudness': '-4.162',
#   'mode': '1',
#   'speechiness': '0.13699999999999998',
#   'acousticness': '0.0254',
#   'instrumentalness': '0.0078',
#   'liveness': '0.124',
#   'valence': '0.038',
#   'tempo': '130.826',
#   'type': 'audio_features',
#   'id': '0XfQbq7DaMOmVXgQ71eA6E',
#   'uri': 'spotify:track:0XfQbq7DaMOmVXgQ71eA6E',
#   'track_href': 'https://api.spotify.com/v1/tracks/0XfQbq7DaMOmVXgQ71eA6E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XfQbq7DaMOmVXgQ71eA6E',
#   'duration_ms': '77584',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'kamikaze (+ pulse)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f142')},
#  {'danceability': '0.6940000000000001',
#   'energy': '0.711',
#   'key': '8',
#   'loudness': '-5.525',
#   'mode': '1',
#   'speechiness': '0.221',
#   'acousticness': '0.0397',
#   'instrumentalness': '0.0',
#   'liveness': '0.11199999999999999',
#   'valence': '0.28300000000000003',
#   'tempo': '138.049',
#   'type': 'audio_features',
#   'id': '0LLeuNBWPOg3XA73yab3PT',
#   'uri': 'spotify:track:0LLeuNBWPOg3XA73yab3PT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0LLeuNBWPOg3XA73yab3PT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LLeuNBWPOg3XA73yab3PT',
#   'duration_ms': '127524',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'T.R.U. (Totally Rotten Underground)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f143')},
#  {'danceability': '0.774',
#   'energy': '0.7509999999999999',
#   'key': '1',
#   'loudness': '-2.445',
#   'mode': '1',
#   'speechiness': '0.198',
#   'acousticness': '0.0614',
#   'instrumentalness': '0.0',
#   'liveness': '0.0728',
#   'valence': '0.18899999999999997',
#   'tempo': '219.96',
#   'type': 'audio_features',
#   'id': '37gqBnUAZe8BY8WR56kDNk',
#   'uri': 'spotify:track:37gqBnUAZe8BY8WR56kDNk',
#   'track_href': 'https://api.spotify.com/v1/tracks/37gqBnUAZe8BY8WR56kDNk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37gqBnUAZe8BY8WR56kDNk',
#   'duration_ms': '140326',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'I Put My Dick in Your Mental',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f144')},
#  {'danceability': '0.893',
#   'energy': '0.907',
#   'key': '11',
#   'loudness': '-10.405999999999999',
#   'mode': '1',
#   'speechiness': '0.36700000000000005',
#   'acousticness': '0.152',
#   'instrumentalness': '0.0311',
#   'liveness': '0.5579999999999999',
#   'valence': '0.302',
#   'tempo': '199.942',
#   'type': 'audio_features',
#   'id': '2ggqfj97qyiORmXoVFzP5j',
#   'uri': 'spotify:track:2ggqfj97qyiORmXoVFzP5j',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ggqfj97qyiORmXoVFzP5j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ggqfj97qyiORmXoVFzP5j',
#   'duration_ms': '121979',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Andromeda',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f145')},
#  {'danceability': '0.8640000000000001',
#   'energy': '0.365',
#   'key': '8',
#   'loudness': '-10.219',
#   'mode': '1',
#   'speechiness': '0.0655',
#   'acousticness': '0.187',
#   'instrumentalness': '0.0',
#   'liveness': '0.11599999999999999',
#   'valence': '0.0478',
#   'tempo': '189.938',
#   'type': 'audio_features',
#   'id': '7EL7ifncK2PWFYThJjzR25',
#   'uri': 'spotify:track:7EL7ifncK2PWFYThJjzR25',
#   'track_href': 'https://api.spotify.com/v1/tracks/7EL7ifncK2PWFYThJjzR25',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EL7ifncK2PWFYThJjzR25',
#   'duration_ms': '101172',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'BRAINFOOD',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f146')},
#  {'danceability': '0.736',
#   'energy': '0.932',
#   'key': '1',
#   'loudness': '-3.7260000000000004',
#   'mode': '1',
#   'speechiness': '0.271',
#   'acousticness': '0.146',
#   'instrumentalness': '0.0025',
#   'liveness': '0.182',
#   'valence': '0.18',
#   'tempo': '124.514',
#   'type': 'audio_features',
#   'id': '0QiF3l617bIKVrkBqgdMHE',
#   'uri': 'spotify:track:0QiF3l617bIKVrkBqgdMHE',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QiF3l617bIKVrkBqgdMHE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QiF3l617bIKVrkBqgdMHE',
#   'duration_ms': '115775',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Troll Under the Bridge',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f147')},
#  {'danceability': '0.825',
#   'energy': '0.7609999999999999',
#   'key': '8',
#   'loudness': '-5.388999999999999',
#   'mode': '1',
#   'speechiness': '0.10400000000000001',
#   'acousticness': '0.0111',
#   'instrumentalness': '0.00359',
#   'liveness': '0.33399999999999996',
#   'valence': '0.161',
#   'tempo': '149.97',
#   'type': 'audio_features',
#   'id': '5o7ZDvfOry1MNhNLBOJulo',
#   'uri': 'spotify:track:5o7ZDvfOry1MNhNLBOJulo',
#   'track_href': 'https://api.spotify.com/v1/tracks/5o7ZDvfOry1MNhNLBOJulo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5o7ZDvfOry1MNhNLBOJulo',
#   'duration_ms': '163371',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': '1000 Rounds',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f148')},
#  {'danceability': '0.767',
#   'energy': '0.5760000000000001',
#   'key': '10',
#   'loudness': '-9.683',
#   'mode': '0',
#   'speechiness': '0.256',
#   'acousticness': '0.145',
#   'instrumentalness': '2.61e-06',
#   'liveness': '0.0968',
#   'valence': '0.187',
#   'tempo': '139.99',
#   'type': 'audio_features',
#   'id': '1umsRbM7L4ju7rn9aU8Ju6',
#   'uri': 'spotify:track:1umsRbM7L4ju7rn9aU8Ju6',
#   'track_href': 'https://api.spotify.com/v1/tracks/1umsRbM7L4ju7rn9aU8Ju6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1umsRbM7L4ju7rn9aU8Ju6',
#   'duration_ms': '96062',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Sacrifice',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f149')},
#  {'danceability': '0.765',
#   'energy': '0.726',
#   'key': '5',
#   'loudness': '-5.58',
#   'mode': '1',
#   'speechiness': '0.191',
#   'acousticness': '0.0077',
#   'instrumentalness': '0.0',
#   'liveness': '0.619',
#   'valence': '0.27',
#   'tempo': '128.014',
#   'type': 'audio_features',
#   'id': '4SKqOHKYU5pgHr5UiVKiQN',
#   'uri': 'spotify:track:4SKqOHKYU5pgHr5UiVKiQN',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SKqOHKYU5pgHr5UiVKiQN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SKqOHKYU5pgHr5UiVKiQN',
#   'duration_ms': '135079',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Backpack',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14a')},
#  {'danceability': '0.617',
#   'energy': '0.541',
#   'key': '6',
#   'loudness': '-4.113',
#   'mode': '1',
#   'speechiness': '0.78',
#   'acousticness': '0.125',
#   'instrumentalness': '0.0',
#   'liveness': '0.369',
#   'valence': '0.43',
#   'tempo': '159.996',
#   'type': 'audio_features',
#   'id': '4Ag89Y7qSUrpxcgRtSzSam',
#   'uri': 'spotify:track:4Ag89Y7qSUrpxcgRtSzSam',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Ag89Y7qSUrpxcgRtSzSam',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ag89Y7qSUrpxcgRtSzSam',
#   'duration_ms': '107999',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'D(R)Own',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14b')},
#  {'danceability': '0.755',
#   'energy': '0.298',
#   'key': '1',
#   'loudness': '-15.032',
#   'mode': '1',
#   'speechiness': '0.0915',
#   'acousticness': '0.154',
#   'instrumentalness': '0.32899999999999996',
#   'liveness': '0.10099999999999999',
#   'valence': '0.0372',
#   'tempo': '199.958',
#   'type': 'audio_features',
#   'id': '28xkYPSP0P5xu5vT6MQfCy',
#   'uri': 'spotify:track:28xkYPSP0P5xu5vT6MQfCy',
#   'track_href': 'https://api.spotify.com/v1/tracks/28xkYPSP0P5xu5vT6MQfCy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28xkYPSP0P5xu5vT6MQfCy',
#   'duration_ms': '123054',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Okay,ButThisIsTheLastTime',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14c')},
#  {'danceability': '0.8140000000000001',
#   'energy': '0.575',
#   'key': '11',
#   'loudness': '-9.635',
#   'mode': '1',
#   'speechiness': '0.0635',
#   'acousticness': '0.172',
#   'instrumentalness': '0.000291',
#   'liveness': '0.109',
#   'valence': '0.28800000000000003',
#   'tempo': '120.00399999999999',
#   'type': 'audio_features',
#   'id': '3uE1swbcRp5BrO64UNy6Ex',
#   'uri': 'spotify:track:3uE1swbcRp5BrO64UNy6Ex',
#   'track_href': 'https://api.spotify.com/v1/tracks/3uE1swbcRp5BrO64UNy6Ex',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3uE1swbcRp5BrO64UNy6Ex',
#   'duration_ms': '192833',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'TakingOutTheTrash',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14d')},
#  {'danceability': '0.812',
#   'energy': '0.813',
#   'key': '10',
#   'loudness': '-5.582999999999999',
#   'mode': '0',
#   'speechiness': '0.0984',
#   'acousticness': '0.0987',
#   'instrumentalness': '0.00015',
#   'liveness': '0.0758',
#   'valence': '0.348',
#   'tempo': '128.066',
#   'type': 'audio_features',
#   'id': '3KJrwOuqiEwHq6QTreZT61',
#   'uri': 'spotify:track:3KJrwOuqiEwHq6QTreZT61',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KJrwOuqiEwHq6QTreZT61',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KJrwOuqiEwHq6QTreZT61',
#   'duration_ms': '180880',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Io sono qui',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14e')},
#  {'danceability': '0.8490000000000001',
#   'energy': '0.648',
#   'key': '7',
#   'loudness': '-6.188',
#   'mode': '1',
#   'speechiness': '0.0832',
#   'acousticness': '0.0725',
#   'instrumentalness': '0.00592',
#   'liveness': '0.0984',
#   'valence': '0.196',
#   'tempo': '212.15',
#   'type': 'audio_features',
#   'id': '4irYeuAi87yyGHcI4h9s0x',
#   'uri': 'spotify:track:4irYeuAi87yyGHcI4h9s0x',
#   'track_href': 'https://api.spotify.com/v1/tracks/4irYeuAi87yyGHcI4h9s0x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4irYeuAi87yyGHcI4h9s0x',
#   'duration_ms': '111020',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Paris',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f14f')},
#  {'danceability': '0.602',
#   'energy': '0.578',
#   'key': '0',
#   'loudness': '-5.61',
#   'mode': '1',
#   'speechiness': '0.0283',
#   'acousticness': '0.0343',
#   'instrumentalness': '0.0',
#   'liveness': '0.16399999999999998',
#   'valence': '0.156',
#   'tempo': '114.956',
#   'type': 'audio_features',
#   'id': '4QhUXx4ON40TIBrZIlnIke',
#   'uri': 'spotify:track:4QhUXx4ON40TIBrZIlnIke',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QhUXx4ON40TIBrZIlnIke',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QhUXx4ON40TIBrZIlnIke',
#   'duration_ms': '186261',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Murder',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f150')},
#  {'danceability': '0.8759999999999999',
#   'energy': '0.768',
#   'key': '7',
#   'loudness': '-6.606',
#   'mode': '1',
#   'speechiness': '0.201',
#   'acousticness': '0.11199999999999999',
#   'instrumentalness': '1.21e-05',
#   'liveness': '0.28300000000000003',
#   'valence': '0.72',
#   'tempo': '111.958',
#   'type': 'audio_features',
#   'id': '09320vyX4qHd4GjHIpy5w0',
#   'uri': 'spotify:track:09320vyX4qHd4GjHIpy5w0',
#   'track_href': 'https://api.spotify.com/v1/tracks/09320vyX4qHd4GjHIpy5w0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09320vyX4qHd4GjHIpy5w0',
#   'duration_ms': '124676',
#   'time_signature': '5',
#   'genre': 'Dark Trap',
#   'song_name': "High 'N Mighty",
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f151')},
#  {'danceability': '0.777',
#   'energy': '0.711',
#   'key': '0',
#   'loudness': '-3.9019999999999997',
#   'mode': '1',
#   'speechiness': '0.13699999999999998',
#   'acousticness': '0.312',
#   'instrumentalness': '0.0',
#   'liveness': '0.205',
#   'valence': '0.293',
#   'tempo': '139.97299999999998',
#   'type': 'audio_features',
#   'id': '2SZLtfY7dz7NLSxxnvDDis',
#   'uri': 'spotify:track:2SZLtfY7dz7NLSxxnvDDis',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SZLtfY7dz7NLSxxnvDDis',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SZLtfY7dz7NLSxxnvDDis',
#   'duration_ms': '153685',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Euronymous',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f152')},
#  {'danceability': '0.8290000000000001',
#   'energy': '0.59',
#   'key': '9',
#   'loudness': '-7.818',
#   'mode': '0',
#   'speechiness': '0.263',
#   'acousticness': '0.0391',
#   'instrumentalness': '0.0107',
#   'liveness': '0.114',
#   'valence': '0.332',
#   'tempo': '112.97',
#   'type': 'audio_features',
#   'id': '0KRKqIJPX6LT9v1ZQGbfn7',
#   'uri': 'spotify:track:0KRKqIJPX6LT9v1ZQGbfn7',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KRKqIJPX6LT9v1ZQGbfn7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KRKqIJPX6LT9v1ZQGbfn7',
#   'duration_ms': '127128',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Hades',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f153')},
#  {'danceability': '0.7829999999999999',
#   'energy': '0.929',
#   'key': '11',
#   'loudness': '0.551',
#   'mode': '0',
#   'speechiness': '0.0893',
#   'acousticness': '0.2',
#   'instrumentalness': '0.00414',
#   'liveness': '0.6890000000000001',
#   'valence': '0.152',
#   'tempo': '118.03',
#   'type': 'audio_features',
#   'id': '0jsbEBnXWgHLkvjV49vYVG',
#   'uri': 'spotify:track:0jsbEBnXWgHLkvjV49vYVG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0jsbEBnXWgHLkvjV49vYVG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jsbEBnXWgHLkvjV49vYVG',
#   'duration_ms': '134447',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Nails',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f154')},
#  {'danceability': '0.787',
#   'energy': '0.727',
#   'key': '1',
#   'loudness': '-7.194',
#   'mode': '1',
#   'speechiness': '0.265',
#   'acousticness': '0.000997',
#   'instrumentalness': '0.0017',
#   'liveness': '0.376',
#   'valence': '0.21',
#   'tempo': '141.52',
#   'type': 'audio_features',
#   'id': '0wxwXyrJYHyGUKlBaCIhgp',
#   'uri': 'spotify:track:0wxwXyrJYHyGUKlBaCIhgp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wxwXyrJYHyGUKlBaCIhgp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wxwXyrJYHyGUKlBaCIhgp',
#   'duration_ms': '140038',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Squeeze',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f155')},
#  {'danceability': '0.705',
#   'energy': '0.648',
#   'key': '4',
#   'loudness': '-10.467',
#   'mode': '0',
#   'speechiness': '0.141',
#   'acousticness': '0.00476',
#   'instrumentalness': '0.000595',
#   'liveness': '0.373',
#   'valence': '0.39799999999999996',
#   'tempo': '130.037',
#   'type': 'audio_features',
#   'id': '0vUhboOWxdj97denl4T91p',
#   'uri': 'spotify:track:0vUhboOWxdj97denl4T91p',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vUhboOWxdj97denl4T91p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vUhboOWxdj97denl4T91p',
#   'duration_ms': '155350',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'No Teeth',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f156')},
#  {'danceability': '0.69',
#   'energy': '0.76',
#   'key': '1',
#   'loudness': '-5.431',
#   'mode': '1',
#   'speechiness': '0.0895',
#   'acousticness': '0.0525',
#   'instrumentalness': '0.0',
#   'liveness': '0.134',
#   'valence': '0.0797',
#   'tempo': '125.01299999999999',
#   'type': 'audio_features',
#   'id': '6xEnbXM1us9fDJy2LC0lru',
#   'uri': 'spotify:track:6xEnbXM1us9fDJy2LC0lru',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xEnbXM1us9fDJy2LC0lru',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xEnbXM1us9fDJy2LC0lru',
#   'duration_ms': '154929',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Bang Ya Fucking Head',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f157')},
#  {'danceability': '0.799',
#   'energy': '0.966',
#   'key': '0',
#   'loudness': '-4.586',
#   'mode': '1',
#   'speechiness': '0.366',
#   'acousticness': '0.08900000000000001',
#   'instrumentalness': '0.0',
#   'liveness': '0.6579999999999999',
#   'valence': '0.8640000000000001',
#   'tempo': '139.967',
#   'type': 'audio_features',
#   'id': '4ZOxwKHoHlhIZPzucOUVoY',
#   'uri': 'spotify:track:4ZOxwKHoHlhIZPzucOUVoY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZOxwKHoHlhIZPzucOUVoY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZOxwKHoHlhIZPzucOUVoY',
#   'duration_ms': '137221',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'BLUE JUICE',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f158')},
#  {'danceability': '0.9359999999999999',
#   'energy': '0.47600000000000003',
#   'key': '1',
#   'loudness': '-11.439',
#   'mode': '1',
#   'speechiness': '0.40299999999999997',
#   'acousticness': '0.0139',
#   'instrumentalness': '0.0',
#   'liveness': '0.402',
#   'valence': '0.363',
#   'tempo': '121.979',
#   'type': 'audio_features',
#   'id': '2AoJ1NSLrqfppo6oT5Bqc8',
#   'uri': 'spotify:track:2AoJ1NSLrqfppo6oT5Bqc8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2AoJ1NSLrqfppo6oT5Bqc8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2AoJ1NSLrqfppo6oT5Bqc8',
#   'duration_ms': '175543',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Loch Ness',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f159')},
#  {'danceability': '0.838',
#   'energy': '0.634',
#   'key': '8',
#   'loudness': '-8.076',
#   'mode': '1',
#   'speechiness': '0.0931',
#   'acousticness': '0.005370000000000001',
#   'instrumentalness': '0.0',
#   'liveness': '0.111',
#   'valence': '0.22399999999999998',
#   'tempo': '114.771',
#   'type': 'audio_features',
#   'id': '30Q5BsSJBLb9SGm0BtuJj4',
#   'uri': 'spotify:track:30Q5BsSJBLb9SGm0BtuJj4',
#   'track_href': 'https://api.spotify.com/v1/tracks/30Q5BsSJBLb9SGm0BtuJj4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/30Q5BsSJBLb9SGm0BtuJj4',
#   'duration_ms': '168202',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Hold Uh',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15a')},
#  {'danceability': '0.9640000000000001',
#   'energy': '0.51',
#   'key': '1',
#   'loudness': '-7.002999999999999',
#   'mode': '1',
#   'speechiness': '0.242',
#   'acousticness': '0.00021400000000000002',
#   'instrumentalness': '6.47e-06',
#   'liveness': '0.0549',
#   'valence': '0.474',
#   'tempo': '130.028',
#   'type': 'audio_features',
#   'id': '3Xi5SYx5pOqte5tLKHEmPb',
#   'uri': 'spotify:track:3Xi5SYx5pOqte5tLKHEmPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Xi5SYx5pOqte5tLKHEmPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Xi5SYx5pOqte5tLKHEmPb',
#   'duration_ms': '136650',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Bone Saw',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15b')},
#  {'danceability': '0.83',
#   'energy': '0.387',
#   'key': '10',
#   'loudness': '-12.908',
#   'mode': '0',
#   'speechiness': '0.345',
#   'acousticness': '0.0858',
#   'instrumentalness': '0.40700000000000003',
#   'liveness': '0.0926',
#   'valence': '0.561',
#   'tempo': '120.006',
#   'type': 'audio_features',
#   'id': '2bmSQxuradc103RXzvjTkE',
#   'uri': 'spotify:track:2bmSQxuradc103RXzvjTkE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bmSQxuradc103RXzvjTkE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bmSQxuradc103RXzvjTkE',
#   'duration_ms': '132193',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Coffin Wave',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15c')},
#  {'danceability': '0.455',
#   'energy': '0.525',
#   'key': '5',
#   'loudness': '-12.692',
#   'mode': '0',
#   'speechiness': '0.0455',
#   'acousticness': '0.136',
#   'instrumentalness': '0.7340000000000001',
#   'liveness': '0.125',
#   'valence': '0.27899999999999997',
#   'tempo': '119.999',
#   'type': 'audio_features',
#   'id': '2Tu4kHEeIVFn6Re2ybm2lQ',
#   'uri': 'spotify:track:2Tu4kHEeIVFn6Re2ybm2lQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Tu4kHEeIVFn6Re2ybm2lQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tu4kHEeIVFn6Re2ybm2lQ',
#   'duration_ms': '159974',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'OhNo!',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15d')},
#  {'danceability': '0.748',
#   'energy': '0.573',
#   'key': '9',
#   'loudness': '-9.907',
#   'mode': '1',
#   'speechiness': '0.0543',
#   'acousticness': '0.484',
#   'instrumentalness': '2.59e-06',
#   'liveness': '0.0929',
#   'valence': '0.193',
#   'tempo': '117.962',
#   'type': 'audio_features',
#   'id': '0QVG9r2otIXoWCHyh09SqU',
#   'uri': 'spotify:track:0QVG9r2otIXoWCHyh09SqU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QVG9r2otIXoWCHyh09SqU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QVG9r2otIXoWCHyh09SqU',
#   'duration_ms': '195875',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'TheArtOfCremation',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15e')},
#  {'danceability': '0.745',
#   'energy': '0.688',
#   'key': '6',
#   'loudness': '-9.263',
#   'mode': '0',
#   'speechiness': '0.10300000000000001',
#   'acousticness': '0.264',
#   'instrumentalness': '0.009059999999999999',
#   'liveness': '0.077',
#   'valence': '0.522',
#   'tempo': '114.99700000000001',
#   'type': 'audio_features',
#   'id': '78w3kPqUAwDjADBY3xAGHl',
#   'uri': 'spotify:track:78w3kPqUAwDjADBY3xAGHl',
#   'track_href': 'https://api.spotify.com/v1/tracks/78w3kPqUAwDjADBY3xAGHl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78w3kPqUAwDjADBY3xAGHl',
#   'duration_ms': '107750',
#   'time_signature': '5',
#   'genre': 'Dark Trap',
#   'song_name': 'OakGroveRoad',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f15f')},
#  {'danceability': '0.722',
#   'energy': '0.519',
#   'key': '0',
#   'loudness': '-12.870999999999999',
#   'mode': '1',
#   'speechiness': '0.0516',
#   'acousticness': '0.0253',
#   'instrumentalness': '0.0114',
#   'liveness': '0.18899999999999997',
#   'valence': '0.128',
#   'tempo': '199.97400000000002',
#   'type': 'audio_features',
#   'id': '02803el8p3mKqcJzJ3Agpp',
#   'uri': 'spotify:track:02803el8p3mKqcJzJ3Agpp',
#   'track_href': 'https://api.spotify.com/v1/tracks/02803el8p3mKqcJzJ3Agpp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02803el8p3mKqcJzJ3Agpp',
#   'duration_ms': '143833',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'WhatWasThat',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f160')},
#  {'danceability': '0.657',
#   'energy': '0.473',
#   'key': '1',
#   'loudness': '-12.050999999999998',
#   'mode': '1',
#   'speechiness': '0.0368',
#   'acousticness': '0.23199999999999998',
#   'instrumentalness': '0.026000000000000002',
#   'liveness': '0.10800000000000001',
#   'valence': '0.153',
#   'tempo': '150.029',
#   'type': 'audio_features',
#   'id': '5Njf3sGQoxQJqcR4gUbttZ',
#   'uri': 'spotify:track:5Njf3sGQoxQJqcR4gUbttZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Njf3sGQoxQJqcR4gUbttZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Njf3sGQoxQJqcR4gUbttZ',
#   'duration_ms': '114500',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'FunnyToSeeYouHere',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f161')},
#  {'danceability': '0.9359999999999999',
#   'energy': '0.474',
#   'key': '1',
#   'loudness': '-9.693999999999999',
#   'mode': '1',
#   'speechiness': '0.39299999999999996',
#   'acousticness': '0.0213',
#   'instrumentalness': '0.0',
#   'liveness': '0.111',
#   'valence': '0.168',
#   'tempo': '129.999',
#   'type': 'audio_features',
#   'id': '7BLFY8GsDyUkaARTv0uwKH',
#   'uri': 'spotify:track:7BLFY8GsDyUkaARTv0uwKH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BLFY8GsDyUkaARTv0uwKH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BLFY8GsDyUkaARTv0uwKH',
#   'duration_ms': '166910',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'John Dee',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f162')},
#  {'danceability': '0.765',
#   'energy': '0.62',
#   'key': '10',
#   'loudness': '-7.337999999999999',
#   'mode': '0',
#   'speechiness': '0.14',
#   'acousticness': '0.0643',
#   'instrumentalness': '0.00018999999999999998',
#   'liveness': '0.16',
#   'valence': '0.218',
#   'tempo': '219.808',
#   'type': 'audio_features',
#   'id': '2bmjoUqk5ELqted5imBtMd',
#   'uri': 'spotify:track:2bmjoUqk5ELqted5imBtMd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bmjoUqk5ELqted5imBtMd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bmjoUqk5ELqted5imBtMd',
#   'duration_ms': '131350',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Kybalion',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f163')},
#  {'danceability': '0.65',
#   'energy': '0.9520000000000001',
#   'key': '11',
#   'loudness': '-2.6860000000000004',
#   'mode': '1',
#   'speechiness': '0.5',
#   'acousticness': '0.0912',
#   'instrumentalness': '0.35100000000000003',
#   'liveness': '0.337',
#   'valence': '0.256',
#   'tempo': '209.998',
#   'type': 'audio_features',
#   'id': '4Uk53I7Lz6bzctGoyNxf8W',
#   'uri': 'spotify:track:4Uk53I7Lz6bzctGoyNxf8W',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Uk53I7Lz6bzctGoyNxf8W',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Uk53I7Lz6bzctGoyNxf8W',
#   'duration_ms': '122211',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'Killer',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f164')},
#  {'danceability': '0.386',
#   'energy': '0.9359999999999999',
#   'key': '7',
#   'loudness': '-5.551',
#   'mode': '1',
#   'speechiness': '0.604',
#   'acousticness': '0.10099999999999999',
#   'instrumentalness': '0.0019199999999999998',
#   'liveness': '0.381',
#   'valence': '0.193',
#   'tempo': '190.15',
#   'type': 'audio_features',
#   'id': '7FoW7q7uZGOHlGi9w5mUxN',
#   'uri': 'spotify:track:7FoW7q7uZGOHlGi9w5mUxN',
#   'track_href': 'https://api.spotify.com/v1/tracks/7FoW7q7uZGOHlGi9w5mUxN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FoW7q7uZGOHlGi9w5mUxN',
#   'duration_ms': '197053',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': '608',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f165')},
#  {'danceability': '0.563',
#   'energy': '0.68',
#   'key': '0',
#   'loudness': '-5.952999999999999',
#   'mode': '1',
#   'speechiness': '0.39',
#   'acousticness': '0.23600000000000002',
#   'instrumentalness': '3.28e-05',
#   'liveness': '0.122',
#   'valence': '0.0396',
#   'tempo': '180.218',
#   'type': 'audio_features',
#   'id': '6dm3aVYUAfZtdFeLAG6R9F',
#   'uri': 'spotify:track:6dm3aVYUAfZtdFeLAG6R9F',
#   'track_href': 'https://api.spotify.com/v1/tracks/6dm3aVYUAfZtdFeLAG6R9F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dm3aVYUAfZtdFeLAG6R9F',
#   'duration_ms': '110000',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'Eternal Dreams',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f166')},
#  {'danceability': '0.777',
#   'energy': '0.902',
#   'key': '1',
#   'loudness': '-3.915',
#   'mode': '1',
#   'speechiness': '0.349',
#   'acousticness': '0.0905',
#   'instrumentalness': '0.0',
#   'liveness': '0.275',
#   'valence': '0.462',
#   'tempo': '129.985',
#   'type': 'audio_features',
#   'id': '5QArbhcHhpW48U4cK3Joj9',
#   'uri': 'spotify:track:5QArbhcHhpW48U4cK3Joj9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QArbhcHhpW48U4cK3Joj9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QArbhcHhpW48U4cK3Joj9',
#   'duration_ms': '134844',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Nightmare Choir (I Been Asleep Too Long)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f167')},
#  {'danceability': '0.607',
#   'energy': '0.7490000000000001',
#   'key': '2',
#   'loudness': '-4.497',
#   'mode': '1',
#   'speechiness': '0.0728',
#   'acousticness': '0.006409999999999999',
#   'instrumentalness': '7.659999999999999e-05',
#   'liveness': '0.23399999999999999',
#   'valence': '0.18',
#   'tempo': '121.829',
#   'type': 'audio_features',
#   'id': '2Bkfvi3pCcwoJwnmd45OnA',
#   'uri': 'spotify:track:2Bkfvi3pCcwoJwnmd45OnA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Bkfvi3pCcwoJwnmd45OnA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Bkfvi3pCcwoJwnmd45OnA',
#   'duration_ms': '126224',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Exodus',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f168')},
#  {'danceability': '0.628',
#   'energy': '0.573',
#   'key': '1',
#   'loudness': '-8.161',
#   'mode': '1',
#   'speechiness': '0.0673',
#   'acousticness': '0.0036200000000000004',
#   'instrumentalness': '0.0',
#   'liveness': '0.0874',
#   'valence': '0.0387',
#   'tempo': '115.50299999999999',
#   'type': 'audio_features',
#   'id': '2XLdbJRfl2UHHzIurEFgAA',
#   'uri': 'spotify:track:2XLdbJRfl2UHHzIurEFgAA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XLdbJRfl2UHHzIurEFgAA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XLdbJRfl2UHHzIurEFgAA',
#   'duration_ms': '132702',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'Vengeance',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f169')},
#  {'danceability': '0.46799999999999997',
#   'energy': '0.325',
#   'key': '1',
#   'loudness': '-8.267000000000001',
#   'mode': '1',
#   'speechiness': '0.245',
#   'acousticness': '0.115',
#   'instrumentalness': '0.726',
#   'liveness': '0.109',
#   'valence': '0.0387',
#   'tempo': '191.18599999999998',
#   'type': 'audio_features',
#   'id': '2Iwf4sAnEgkuxxnJ61du8z',
#   'uri': 'spotify:track:2Iwf4sAnEgkuxxnJ61du8z',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Iwf4sAnEgkuxxnJ61du8z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Iwf4sAnEgkuxxnJ61du8z',
#   'duration_ms': '90645',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': 'Claustrophobia',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16a')},
#  {'danceability': '0.512',
#   'energy': '0.44',
#   'key': '1',
#   'loudness': '-7.816',
#   'mode': '1',
#   'speechiness': '0.233',
#   'acousticness': '0.00386',
#   'instrumentalness': '3.11e-06',
#   'liveness': '0.233',
#   'valence': '0.132',
#   'tempo': '207.99200000000002',
#   'type': 'audio_features',
#   'id': '04MKRNwoX7TqQkA0ZrtMbC',
#   'uri': 'spotify:track:04MKRNwoX7TqQkA0ZrtMbC',
#   'track_href': 'https://api.spotify.com/v1/tracks/04MKRNwoX7TqQkA0ZrtMbC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04MKRNwoX7TqQkA0ZrtMbC',
#   'duration_ms': '86805',
#   'time_signature': '1',
#   'genre': 'Dark Trap',
#   'song_name': 'Rearranged',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16b')},
#  {'danceability': '0.504',
#   'energy': '0.48',
#   'key': '3',
#   'loudness': '-8.885',
#   'mode': '1',
#   'speechiness': '0.045',
#   'acousticness': '0.8320000000000001',
#   'instrumentalness': '0.000252',
#   'liveness': '0.10099999999999999',
#   'valence': '0.878',
#   'tempo': '173.993',
#   'type': 'audio_features',
#   'id': '5DV8yoddFyjLVfRT6pfAht',
#   'uri': 'spotify:track:5DV8yoddFyjLVfRT6pfAht',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DV8yoddFyjLVfRT6pfAht',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DV8yoddFyjLVfRT6pfAht',
#   'duration_ms': '176901',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Paralax',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16c')},
#  {'danceability': '0.608',
#   'energy': '0.662',
#   'key': '1',
#   'loudness': '-8.474',
#   'mode': '1',
#   'speechiness': '0.0338',
#   'acousticness': '0.0246',
#   'instrumentalness': '7.85e-06',
#   'liveness': '0.0409',
#   'valence': '0.0637',
#   'tempo': '117.031',
#   'type': 'audio_features',
#   'id': '1XKlzwkRZmyrz2OjVqNIyl',
#   'uri': 'spotify:track:1XKlzwkRZmyrz2OjVqNIyl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XKlzwkRZmyrz2OjVqNIyl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XKlzwkRZmyrz2OjVqNIyl',
#   'duration_ms': '98482',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Exsanguination',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16d')},
#  {'danceability': '0.7829999999999999',
#   'energy': '0.684',
#   'key': '5',
#   'loudness': '-7.435',
#   'mode': '1',
#   'speechiness': '0.0358',
#   'acousticness': '0.00873',
#   'instrumentalness': '0.0005480000000000001',
#   'liveness': '0.222',
#   'valence': '0.17300000000000001',
#   'tempo': '141.037',
#   'type': 'audio_features',
#   'id': '78SOPBLZeBjDQ9NVTePOPE',
#   'uri': 'spotify:track:78SOPBLZeBjDQ9NVTePOPE',
#   'track_href': 'https://api.spotify.com/v1/tracks/78SOPBLZeBjDQ9NVTePOPE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78SOPBLZeBjDQ9NVTePOPE',
#   'duration_ms': '117447',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Mutiny',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16e')},
#  {'danceability': '0.6679999999999999',
#   'energy': '0.479',
#   'key': '10',
#   'loudness': '-7.321000000000001',
#   'mode': '0',
#   'speechiness': '0.0436',
#   'acousticness': '0.0612',
#   'instrumentalness': '0.408',
#   'liveness': '0.12',
#   'valence': '0.102',
#   'tempo': '162.12',
#   'type': 'audio_features',
#   'id': '1NJel5c5LSc9Ac7UAeoJtp',
#   'uri': 'spotify:track:1NJel5c5LSc9Ac7UAeoJtp',
#   'track_href': 'https://api.spotify.com/v1/tracks/1NJel5c5LSc9Ac7UAeoJtp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NJel5c5LSc9Ac7UAeoJtp',
#   'duration_ms': '128888',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Centipede',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f16f')},
#  {'danceability': '0.528',
#   'energy': '0.617',
#   'key': '8',
#   'loudness': '-6.122999999999999',
#   'mode': '1',
#   'speechiness': '0.0657',
#   'acousticness': '0.20199999999999999',
#   'instrumentalness': '0.153',
#   'liveness': '0.146',
#   'valence': '0.0356',
#   'tempo': '119.04700000000001',
#   'type': 'audio_features',
#   'id': '18hIrODUziu3KyUxeDKlcq',
#   'uri': 'spotify:track:18hIrODUziu3KyUxeDKlcq',
#   'track_href': 'https://api.spotify.com/v1/tracks/18hIrODUziu3KyUxeDKlcq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18hIrODUziu3KyUxeDKlcq',
#   'duration_ms': '199664',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Грустная сука',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f170')},
#  {'danceability': '0.7959999999999999',
#   'energy': '0.7559999999999999',
#   'key': '8',
#   'loudness': '-2.244',
#   'mode': '1',
#   'speechiness': '0.0572',
#   'acousticness': '0.0059',
#   'instrumentalness': '0.006790000000000001',
#   'liveness': '0.128',
#   'valence': '0.0292',
#   'tempo': '120.01',
#   'type': 'audio_features',
#   'id': '04xhIz4DiBGDECn7kIFodv',
#   'uri': 'spotify:track:04xhIz4DiBGDECn7kIFodv',
#   'track_href': 'https://api.spotify.com/v1/tracks/04xhIz4DiBGDECn7kIFodv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04xhIz4DiBGDECn7kIFodv',
#   'duration_ms': '112000',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'This World Is Sick',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f171')},
#  {'danceability': '0.299',
#   'energy': '0.381',
#   'key': '3',
#   'loudness': '-6.9510000000000005',
#   'mode': '0',
#   'speechiness': '0.038',
#   'acousticness': '0.445',
#   'instrumentalness': '0.0023',
#   'liveness': '0.0932',
#   'valence': '0.0392',
#   'tempo': '136.46200000000002',
#   'type': 'audio_features',
#   'id': '6Q1LtmZPFRGNZbH6VdarBQ',
#   'uri': 'spotify:track:6Q1LtmZPFRGNZbH6VdarBQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Q1LtmZPFRGNZbH6VdarBQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Q1LtmZPFRGNZbH6VdarBQ',
#   'duration_ms': '234000',
#   'time_signature': '1',
#   'genre': 'Dark Trap',
#   'song_name': 'Пламя',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f172')},
#  {'danceability': '0.644',
#   'energy': '0.64',
#   'key': '8',
#   'loudness': '-7.877000000000001',
#   'mode': '1',
#   'speechiness': '0.0688',
#   'acousticness': '0.00329',
#   'instrumentalness': '0.0',
#   'liveness': '0.146',
#   'valence': '0.175',
#   'tempo': '217.888',
#   'type': 'audio_features',
#   'id': '3uvKXKQxcmjPT7letWh3Pf',
#   'uri': 'spotify:track:3uvKXKQxcmjPT7letWh3Pf',
#   'track_href': 'https://api.spotify.com/v1/tracks/3uvKXKQxcmjPT7letWh3Pf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3uvKXKQxcmjPT7letWh3Pf',
#   'duration_ms': '125048',
#   'time_signature': '3',
#   'genre': 'Dark Trap',
#   'song_name': '2:45',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f173')},
#  {'danceability': '0.473',
#   'energy': '0.843',
#   'key': '1',
#   'loudness': '-5.981',
#   'mode': '1',
#   'speechiness': '0.225',
#   'acousticness': '0.00345',
#   'instrumentalness': '2.5300000000000002e-05',
#   'liveness': '0.102',
#   'valence': '0.24',
#   'tempo': '143.29399999999998',
#   'type': 'audio_features',
#   'id': '1K86gziny1mnNIisKBqzhH',
#   'uri': 'spotify:track:1K86gziny1mnNIisKBqzhH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1K86gziny1mnNIisKBqzhH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1K86gziny1mnNIisKBqzhH',
#   'duration_ms': '183536',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'who is he',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f174')},
#  {'danceability': '0.47100000000000003',
#   'energy': '0.618',
#   'key': '10',
#   'loudness': '-9.965',
#   'mode': '0',
#   'speechiness': '0.10800000000000001',
#   'acousticness': '0.0219',
#   'instrumentalness': '0.006640000000000001',
#   'liveness': '0.16',
#   'valence': '0.0392',
#   'tempo': '110.337',
#   'type': 'audio_features',
#   'id': '7yvTs8trSYMtNNisA0nT73',
#   'uri': 'spotify:track:7yvTs8trSYMtNNisA0nT73',
#   'track_href': 'https://api.spotify.com/v1/tracks/7yvTs8trSYMtNNisA0nT73',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7yvTs8trSYMtNNisA0nT73',
#   'duration_ms': '125500',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Sleeping',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f175')},
#  {'danceability': '0.665',
#   'energy': '0.446',
#   'key': '1',
#   'loudness': '-14.845',
#   'mode': '1',
#   'speechiness': '0.172',
#   'acousticness': '0.069',
#   'instrumentalness': '1.88e-05',
#   'liveness': '0.32299999999999995',
#   'valence': '0.11699999999999999',
#   'tempo': '115.28200000000001',
#   'type': 'audio_features',
#   'id': '3Pk6O7DndRfH1q6UFsCaWm',
#   'uri': 'spotify:track:3Pk6O7DndRfH1q6UFsCaWm',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Pk6O7DndRfH1q6UFsCaWm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Pk6O7DndRfH1q6UFsCaWm',
#   'duration_ms': '156048',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Timeless',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f176')},
#  {'danceability': '0.812',
#   'energy': '0.7070000000000001',
#   'key': '10',
#   'loudness': '-6.815',
#   'mode': '0',
#   'speechiness': '0.0752',
#   'acousticness': '0.23600000000000002',
#   'instrumentalness': '0.0',
#   'liveness': '0.5870000000000001',
#   'valence': '0.248',
#   'tempo': '219.984',
#   'type': 'audio_features',
#   'id': '5mPUo1HP5K4H6hepYHqbZx',
#   'uri': 'spotify:track:5mPUo1HP5K4H6hepYHqbZx',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mPUo1HP5K4H6hepYHqbZx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mPUo1HP5K4H6hepYHqbZx',
#   'duration_ms': '175203',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Pound for Pound',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f177')},
#  {'danceability': '0.262',
#   'energy': '0.897',
#   'key': '4',
#   'loudness': '-2.7119999999999997',
#   'mode': '0',
#   'speechiness': '0.39799999999999996',
#   'acousticness': '0.0237',
#   'instrumentalness': '0.0',
#   'liveness': '0.11',
#   'valence': '0.253',
#   'tempo': '199.65099999999998',
#   'type': 'audio_features',
#   'id': '2x7mBK5ozd9hwneRKMVpkD',
#   'uri': 'spotify:track:2x7mBK5ozd9hwneRKMVpkD',
#   'track_href': 'https://api.spotify.com/v1/tracks/2x7mBK5ozd9hwneRKMVpkD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2x7mBK5ozd9hwneRKMVpkD',
#   'duration_ms': '153104',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Finger Trembling',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f178')},
#  {'danceability': '0.5710000000000001',
#   'energy': '0.865',
#   'key': '8',
#   'loudness': '-4.99',
#   'mode': '1',
#   'speechiness': '0.0397',
#   'acousticness': '0.0042',
#   'instrumentalness': '0.207',
#   'liveness': '0.0906',
#   'valence': '0.177',
#   'tempo': '150.017',
#   'type': 'audio_features',
#   'id': '3kBa1eXqkSvfCLmG8VqQ10',
#   'uri': 'spotify:track:3kBa1eXqkSvfCLmG8VqQ10',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kBa1eXqkSvfCLmG8VqQ10',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kBa1eXqkSvfCLmG8VqQ10',
#   'duration_ms': '166426',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Overload',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f179')},
#  {'danceability': '0.753',
#   'energy': '0.679',
#   'key': '5',
#   'loudness': '-7.0920000000000005',
#   'mode': '0',
#   'speechiness': '0.0349',
#   'acousticness': '0.324',
#   'instrumentalness': '4.210000000000001e-05',
#   'liveness': '0.423',
#   'valence': '0.19',
#   'tempo': '211.954',
#   'type': 'audio_features',
#   'id': '5XAPpyIoYF3QXP34Hv8Pvx',
#   'uri': 'spotify:track:5XAPpyIoYF3QXP34Hv8Pvx',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XAPpyIoYF3QXP34Hv8Pvx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XAPpyIoYF3QXP34Hv8Pvx',
#   'duration_ms': '145078',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Kill Yourself (Part III)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f17a')},
#  {'danceability': '0.935',
#   'energy': '0.429',
#   'key': '1',
#   'loudness': '-6.697',
#   'mode': '1',
#   'speechiness': '0.11800000000000001',
#   'acousticness': '0.0308',
#   'instrumentalness': '0.0',
#   'liveness': '0.102',
#   'valence': '0.0769',
#   'tempo': '139.987',
#   'type': 'audio_features',
#   'id': '4yORBk6ZyYsJpnJchyZevc',
#   'uri': 'spotify:track:4yORBk6ZyYsJpnJchyZevc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yORBk6ZyYsJpnJchyZevc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yORBk6ZyYsJpnJchyZevc',
#   'duration_ms': '123481',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': '2nd Hand',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f17b')},
#  {'danceability': '0.726',
#   'energy': '0.634',
#   'key': '2',
#   'loudness': '-6.843999999999999',
#   'mode': '1',
#   'speechiness': '0.0792',
#   'acousticness': '0.5529999999999999',
# ...
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6i2uFcXqbCxak4yP2h3vDe',
#   'duration_ms': '85972',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Neon Rainbows',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f50e')},
#  {'danceability': '0.769',
#   'energy': '0.541',
#   'key': '7',
#   'loudness': '-6.065',
#   'mode': '1',
#   'speechiness': '0.0413',
#   'acousticness': '0.423',
#   'instrumentalness': '0.00064',
#   'liveness': '0.10099999999999999',
#   'valence': '0.439',
#   'tempo': '160.055',
#   'type': 'audio_features',
#   'id': '6Z3qMV9E3UPSSmt1s5DKnG',
#   'uri': 'spotify:track:6Z3qMV9E3UPSSmt1s5DKnG',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Z3qMV9E3UPSSmt1s5DKnG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Z3qMV9E3UPSSmt1s5DKnG',
#   'duration_ms': '169424',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'FDD',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f50f')},
#  {'danceability': '0.599',
#   'energy': '0.622',
#   'key': '10',
#   'loudness': '-4.313',
#   'mode': '0',
#   'speechiness': '0.264',
#   'acousticness': '0.124',
#   'instrumentalness': '0.00278',
#   'liveness': '0.158',
#   'valence': '0.19899999999999998',
#   'tempo': '183.23',
#   'type': 'audio_features',
#   'id': '24b6djSbUFQtXAdyb3FMbr',
#   'uri': 'spotify:track:24b6djSbUFQtXAdyb3FMbr',
#   'track_href': 'https://api.spotify.com/v1/tracks/24b6djSbUFQtXAdyb3FMbr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24b6djSbUFQtXAdyb3FMbr',
#   'duration_ms': '199827',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'PTSD',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f510')},
#  {'danceability': '0.557',
#   'energy': '0.7390000000000001',
#   'key': '1',
#   'loudness': '-5.473',
#   'mode': '0',
#   'speechiness': '0.525',
#   'acousticness': '0.271',
#   'instrumentalness': '0.0',
#   'liveness': '0.17',
#   'valence': '0.585',
#   'tempo': '167.19799999999998',
#   'type': 'audio_features',
#   'id': '37bREXWmmdy7R2DCES8yCQ',
#   'uri': 'spotify:track:37bREXWmmdy7R2DCES8yCQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/37bREXWmmdy7R2DCES8yCQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37bREXWmmdy7R2DCES8yCQ',
#   'duration_ms': '205439',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Straight Drop X 4',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f511')},
#  {'danceability': '0.8759999999999999',
#   'energy': '0.423',
#   'key': '9',
#   'loudness': '-10.624',
#   'mode': '0',
#   'speechiness': '0.41700000000000004',
#   'acousticness': '0.124',
#   'instrumentalness': '0.0',
#   'liveness': '0.0851',
#   'valence': '0.418',
#   'tempo': '131.297',
#   'type': 'audio_features',
#   'id': '250gr9zMCjCp4hnVdgLwk2',
#   'uri': 'spotify:track:250gr9zMCjCp4hnVdgLwk2',
#   'track_href': 'https://api.spotify.com/v1/tracks/250gr9zMCjCp4hnVdgLwk2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/250gr9zMCjCp4hnVdgLwk2',
#   'duration_ms': '160560',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Ether',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f512')},
#  {'danceability': '0.764',
#   'energy': '0.48700000000000004',
#   'key': '0',
#   'loudness': '-9.818',
#   'mode': '1',
#   'speechiness': '0.07',
#   'acousticness': '0.43799999999999994',
#   'instrumentalness': '0.0',
#   'liveness': '0.0952',
#   'valence': '0.401',
#   'tempo': '144.997',
#   'type': 'audio_features',
#   'id': '0ZdOjc6BbVV8NG1pZmltT3',
#   'uri': 'spotify:track:0ZdOjc6BbVV8NG1pZmltT3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ZdOjc6BbVV8NG1pZmltT3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ZdOjc6BbVV8NG1pZmltT3',
#   'duration_ms': '188261',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Bad Habits',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f513')},
#  {'danceability': '0.7959999999999999',
#   'energy': '0.495',
#   'key': '9',
#   'loudness': '-5.506',
#   'mode': '1',
#   'speechiness': '0.0884',
#   'acousticness': '0.21600000000000003',
#   'instrumentalness': '0.0',
#   'liveness': '0.11599999999999999',
#   'valence': '0.45',
#   'tempo': '148.02',
#   'type': 'audio_features',
#   'id': '1so8ZgQIoaFVAytjD1kkp5',
#   'uri': 'spotify:track:1so8ZgQIoaFVAytjD1kkp5',
#   'track_href': 'https://api.spotify.com/v1/tracks/1so8ZgQIoaFVAytjD1kkp5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1so8ZgQIoaFVAytjD1kkp5',
#   'duration_ms': '149189',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Head Straight',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f514')},
#  {'danceability': '0.7020000000000001',
#   'energy': '0.442',
#   'key': '0',
#   'loudness': '-10.661',
#   'mode': '0',
#   'speechiness': '0.14',
#   'acousticness': '0.065',
#   'instrumentalness': '0.0005769999999999999',
#   'liveness': '0.11199999999999999',
#   'valence': '0.049',
#   'tempo': '172.09',
#   'type': 'audio_features',
#   'id': '79ZT7bbfhXmsFiCNSpL1PQ',
#   'uri': 'spotify:track:79ZT7bbfhXmsFiCNSpL1PQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/79ZT7bbfhXmsFiCNSpL1PQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/79ZT7bbfhXmsFiCNSpL1PQ',
#   'duration_ms': '113027',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Shxdes',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f515')},
#  {'danceability': '0.9129999999999999',
#   'energy': '0.574',
#   'key': '1',
#   'loudness': '-7.022',
#   'mode': '1',
#   'speechiness': '0.298',
#   'acousticness': '0.0334',
#   'instrumentalness': '0.0',
#   'liveness': '0.11900000000000001',
#   'valence': '0.33',
#   'tempo': '196.05599999999998',
#   'type': 'audio_features',
#   'id': '6GzPrIUIyvzccRVMVBK2Aa',
#   'uri': 'spotify:track:6GzPrIUIyvzccRVMVBK2Aa',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GzPrIUIyvzccRVMVBK2Aa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GzPrIUIyvzccRVMVBK2Aa',
#   'duration_ms': '146939',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'GO GETTA',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f516')},
#  {'danceability': '0.496',
#   'energy': '0.542',
#   'key': '6',
#   'loudness': '-11.244000000000002',
#   'mode': '1',
#   'speechiness': '0.0629',
#   'acousticness': '0.0197',
#   'instrumentalness': '7.699999999999999e-06',
#   'liveness': '0.0992',
#   'valence': '0.0937',
#   'tempo': '156.12',
#   'type': 'audio_features',
#   'id': '1jXnBW1Ew8KNb8UR94cak6',
#   'uri': 'spotify:track:1jXnBW1Ew8KNb8UR94cak6',
#   'track_href': 'https://api.spotify.com/v1/tracks/1jXnBW1Ew8KNb8UR94cak6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jXnBW1Ew8KNb8UR94cak6',
#   'duration_ms': '153846',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Tar Lungs',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f517')},
#  {'danceability': '0.5920000000000001',
#   'energy': '0.953',
#   'key': '0',
#   'loudness': '-0.9329999999999999',
#   'mode': '0',
#   'speechiness': '0.377',
#   'acousticness': '0.0031',
#   'instrumentalness': '1.13e-06',
#   'liveness': '0.365',
#   'valence': '0.188',
#   'tempo': '154.996',
#   'type': 'audio_features',
#   'id': '1k9rwbVHqU9S2msC1fiAIi',
#   'uri': 'spotify:track:1k9rwbVHqU9S2msC1fiAIi',
#   'track_href': 'https://api.spotify.com/v1/tracks/1k9rwbVHqU9S2msC1fiAIi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1k9rwbVHqU9S2msC1fiAIi',
#   'duration_ms': '137121',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'POPSHiiT777',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f518')},
#  {'danceability': '0.773',
#   'energy': '0.34600000000000003',
#   'key': '0',
#   'loudness': '-10.398',
#   'mode': '1',
#   'speechiness': '0.0638',
#   'acousticness': '0.0272',
#   'instrumentalness': '0.00048300000000000003',
#   'liveness': '0.106',
#   'valence': '0.106',
#   'tempo': '119.948',
#   'type': 'audio_features',
#   'id': '5iEotd8yFucfmE24yBrhoQ',
#   'uri': 'spotify:track:5iEotd8yFucfmE24yBrhoQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5iEotd8yFucfmE24yBrhoQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5iEotd8yFucfmE24yBrhoQ',
#   'duration_ms': '170918',
#   'time_signature': '5',
#   'genre': 'Dark Trap',
#   'song_name': '.556',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f519')},
#  {'danceability': '0.5820000000000001',
#   'energy': '0.9359999999999999',
#   'key': '2',
#   'loudness': '-2.544',
#   'mode': '1',
#   'speechiness': '0.0803',
#   'acousticness': '0.132',
#   'instrumentalness': '0.0',
#   'liveness': '0.115',
#   'valence': '0.0791',
#   'tempo': '160.018',
#   'type': 'audio_features',
#   'id': '48zQWrXgc8kkrGkK4ffSJf',
#   'uri': 'spotify:track:48zQWrXgc8kkrGkK4ffSJf',
#   'track_href': 'https://api.spotify.com/v1/tracks/48zQWrXgc8kkrGkK4ffSJf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48zQWrXgc8kkrGkK4ffSJf',
#   'duration_ms': '194979',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Dn',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51a')},
#  {'danceability': '0.648',
#   'energy': '0.37200000000000005',
#   'key': '2',
#   'loudness': '-10.342',
#   'mode': '0',
#   'speechiness': '0.38799999999999996',
#   'acousticness': '0.701',
#   'instrumentalness': '1.2e-05',
#   'liveness': '0.504',
#   'valence': '0.395',
#   'tempo': '124.016',
#   'type': 'audio_features',
#   'id': '5PDOBca5JH4AKt44Ew6gLO',
#   'uri': 'spotify:track:5PDOBca5JH4AKt44Ew6gLO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5PDOBca5JH4AKt44Ew6gLO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PDOBca5JH4AKt44Ew6gLO',
#   'duration_ms': '153077',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': "I'm Sorry I'm Broken",
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51b')},
#  {'danceability': '0.77',
#   'energy': '0.6409999999999999',
#   'key': '1',
#   'loudness': '-5.059',
#   'mode': '1',
#   'speechiness': '0.231',
#   'acousticness': '0.0391',
#   'instrumentalness': '0.0',
#   'liveness': '0.38',
#   'valence': '0.303',
#   'tempo': '165.968',
#   'type': 'audio_features',
#   'id': '7nc10nkSdlkFi4j2EO4BD5',
#   'uri': 'spotify:track:7nc10nkSdlkFi4j2EO4BD5',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nc10nkSdlkFi4j2EO4BD5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nc10nkSdlkFi4j2EO4BD5',
#   'duration_ms': '148255',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Dead Inside',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51c')},
#  {'danceability': '0.499',
#   'energy': '0.519',
#   'key': '10',
#   'loudness': '-9.693999999999999',
#   'mode': '0',
#   'speechiness': '0.105',
#   'acousticness': '0.562',
#   'instrumentalness': '4.7499999999999996e-05',
#   'liveness': '0.0903',
#   'valence': '0.24100000000000002',
#   'tempo': '154.436',
#   'type': 'audio_features',
#   'id': '6LhIbVof5uPD42AZvj55KM',
#   'uri': 'spotify:track:6LhIbVof5uPD42AZvj55KM',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LhIbVof5uPD42AZvj55KM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LhIbVof5uPD42AZvj55KM',
#   'duration_ms': '159007',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'They Said the Sky Was the Limit',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51d')},
#  {'danceability': '0.779',
#   'energy': '0.385',
#   'key': '2',
#   'loudness': '-9.789',
#   'mode': '1',
#   'speechiness': '0.0332',
#   'acousticness': '0.0931',
#   'instrumentalness': '0.000897',
#   'liveness': '0.129',
#   'valence': '0.33',
#   'tempo': '128.013',
#   'type': 'audio_features',
#   'id': '5nYvzML0ju29Epv2wOx6Tq',
#   'uri': 'spotify:track:5nYvzML0ju29Epv2wOx6Tq',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nYvzML0ju29Epv2wOx6Tq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nYvzML0ju29Epv2wOx6Tq',
#   'duration_ms': '123576',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Heartbreak (feat. Travis Barker)',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51e')},
#  {'danceability': '0.529',
#   'energy': '0.847',
#   'key': '8',
#   'loudness': '-3.714',
#   'mode': '1',
#   'speechiness': '0.22399999999999998',
#   'acousticness': '0.187',
#   'instrumentalness': '0.0004969999999999999',
#   'liveness': '0.12300000000000001',
#   'valence': '0.375',
#   'tempo': '159.09',
#   'type': 'audio_features',
#   'id': '3d3SXAQRNcnCDJk93LsfWg',
#   'uri': 'spotify:track:3d3SXAQRNcnCDJk93LsfWg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d3SXAQRNcnCDJk93LsfWg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d3SXAQRNcnCDJk93LsfWg',
#   'duration_ms': '135861',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Class Four Freestyle',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f51f')},
#  {'danceability': '0.637',
#   'energy': '0.682',
#   'key': '1',
#   'loudness': '-4.375',
#   'mode': '1',
#   'speechiness': '0.155',
#   'acousticness': '0.145',
#   'instrumentalness': '0.00213',
#   'liveness': '0.122',
#   'valence': '0.38299999999999995',
#   'tempo': '148.988',
#   'type': 'audio_features',
#   'id': '3KFa0h5Gi15UyVhJN02mYH',
#   'uri': 'spotify:track:3KFa0h5Gi15UyVhJN02mYH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KFa0h5Gi15UyVhJN02mYH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KFa0h5Gi15UyVhJN02mYH',
#   'duration_ms': '128042',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Heartless',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f520')},
#  {'danceability': '0.598',
#   'energy': '0.28',
#   'key': '1',
#   'loudness': '-17.949',
#   'mode': '1',
#   'speechiness': '0.386',
#   'acousticness': '0.445',
#   'instrumentalness': '8.81e-06',
#   'liveness': '0.106',
#   'valence': '0.258',
#   'tempo': '144.903',
#   'type': 'audio_features',
#   'id': '0XcMKr1NxGcfSX6NlBV12S',
#   'uri': 'spotify:track:0XcMKr1NxGcfSX6NlBV12S',
#   'track_href': 'https://api.spotify.com/v1/tracks/0XcMKr1NxGcfSX6NlBV12S',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XcMKr1NxGcfSX6NlBV12S',
#   'duration_ms': '248625',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'No Cap',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f521')},
#  {'danceability': '0.767',
#   'energy': '0.669',
#   'key': '1',
#   'loudness': '-5.183',
#   'mode': '1',
#   'speechiness': '0.757',
#   'acousticness': '0.0217',
#   'instrumentalness': '0.000606',
#   'liveness': '0.306',
#   'valence': '0.33899999999999997',
#   'tempo': '170.42700000000002',
#   'type': 'audio_features',
#   'id': '4HojqM4O2Wh6fmkfARuJVc',
#   'uri': 'spotify:track:4HojqM4O2Wh6fmkfARuJVc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4HojqM4O2Wh6fmkfARuJVc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HojqM4O2Wh6fmkfARuJVc',
#   'duration_ms': '81726',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Who You Talking To',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f522')},
#  {'danceability': '0.7490000000000001',
#   'energy': '0.45799999999999996',
#   'key': '1',
#   'loudness': '-9.617',
#   'mode': '1',
#   'speechiness': '0.29600000000000004',
#   'acousticness': '0.007529999999999999',
#   'instrumentalness': '0.00011',
#   'liveness': '0.175',
#   'valence': '0.0481',
#   'tempo': '127.936',
#   'type': 'audio_features',
#   'id': '49wXWCgErMseOh2ya9KQ9M',
#   'uri': 'spotify:track:49wXWCgErMseOh2ya9KQ9M',
#   'track_href': 'https://api.spotify.com/v1/tracks/49wXWCgErMseOh2ya9KQ9M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49wXWCgErMseOh2ya9KQ9M',
#   'duration_ms': '116370',
#   'time_signature': '4',
#   'genre': 'Dark Trap',
#   'song_name': 'Nihilus',
#   'Unnamed: 0': None,
#   'title': None,
#   '_id': ObjectId('601baf55e8ee705b7805f523')},
#  ...]

# %% [markdown]
# ###### Test de correlation de la danceability

# %%
{
    'energy': df.corr('danceability','energy'),
    'loudness': df.corr('danceability','loudness'),
    'valence': df.corr('danceability','valence'),
    'tempo': df.corr('danceability','tempo'),
    'liveness': df.corr('danceability','liveness'),
    'instrumentalness': df.corr('danceability','instrumentalness'),
    'speechiness': df.corr('danceability','speechiness'),
    'acousticness': df.corr('danceability','acousticness'),
}
# Out:
# {'energy': -0.32324758938982884,
#  'loudness': -0.21677558073253783,
#  'valence': 0.36984469824063193,
#  'tempo': -0.16592868259426302,
#  'liveness': -0.1967022785784031,
#  'instrumentalness': -0.06711359015412229,
#  'speechiness': 0.18217692430188007,
#  'acousticness': 0.06990976582404693}

# %% [markdown]
# ###### Test de correlation de la valence

# %%
{
    'energy': df.corr('valence','energy'),
    'loudness': df.corr('valence','loudness'),
    'tempo': df.corr('valence','tempo'),
    'liveness': df.corr('valence','liveness'),
    'instrumentalness': df.corr('valence','instrumentalness'),
    'speechiness': df.corr('valence','speechiness'),
    'acousticness': df.corr('valence','acousticness'),
}
# Out:
# {'energy': -0.013519692624507104,
#  'loudness': 0.08091618276919113,
#  'tempo': 0.05837414725462354,
#  'liveness': -0.025155613532274863,
#  'instrumentalness': -0.2570680360340621,
#  'speechiness': 0.21882903805612033,
#  'acousticness': 0.0993276847644048}

# %% [markdown]
# ##### Quelles sont les armes utilisées par les criminel?
# Retournez par rapport à tous les documents les valeurs uniques de la clef weapon.

# %%
table.distinct("Weapon")

list(table.aggregate([
    { "$group": {
        "_id": "$Weapon", "count" : {"$sum": 1}
    }},
    { "$sort": {"count": -1}}
]))
# Out:
# [{'_id': 'Handgun', 'count': 45748},
#  {'_id': 'Knife', 'count': 19586},
#  {'_id': 'Blunt Object', 'count': 11150},
#  {'_id': 'Shotgun', 'count': 7419},
#  {'_id': 'Rifle', 'count': 4968},
#  {'_id': 'Firearm', 'count': 3629},
#  {'_id': 'Unknown', 'count': 3134},
#  {'_id': 'Strangulation', 'count': 1742},
#  {'_id': 'Fire', 'count': 1254},
#  {'_id': 'Suffocation', 'count': 600},
#  {'_id': 'Drowning', 'count': 265},
#  {'_id': 'Gun', 'count': 212},
#  {'_id': 'Drugs', 'count': 101},
#  {'_id': 'Poison', 'count': 80},
#  {'_id': 'Explosives', 'count': 61},
#  {'_id': 'Fall', 'count': 50}]

# %% [markdown]
# ##### Combien de crimes ont été commis en 1980?

# %%
table.count_documents({"Year":1980})

# %% [markdown]
# ##### Combien de crimes ont été commis par des hommes au Texas?

# %%
table.count_documents({"Perpetrator Sex": "Male", "State": "Texas"})

# %% [markdown]
# ##### Combien de crimes ont été commis par chaque sexe en Alaska?

# %%
maleAndFemalePerpetratorsInAlaska = table.aggregate([
    { "$match": { "State": "Alaska" }},
    { "$group": {"_id": "$Perpetrator Sex", "crimes commis": {"$sum": 1}}},
])

list(maleAndFemalePerpetratorsInAlaska)

# %% [markdown]
# ##### Combien y a-t'il eu de victimes dans chaque état?

# %%
victimInEachState = table.aggregate([
    { "$group" : {
        "_id": "$State", "victimes": {"$sum": "$Victim Count"}
    }},
    { "$sort": { "victimes": -1}}
])

list(victimInEachState)

# %% [markdown]
# ### Bonus

# %% [markdown]
# Installez la librairie streamlit
# Créez un dashboard qui donne la posibilité de séléctionner une année pour retourner un barplot du nombre de crime commis avec chaque arme.

# %%
victimWithEachWeapon = table.aggregate([
    {"$match": {"Year": 1980}},
    { "$group" : {
        "_id": "$Weapon", "victimes": {"$sum": "$Victim Count"}
    }}
])
    
list(victimWithEachWeapon)

# %%
# QCM 2
victimWithEachAge = table.aggregate([
    { "$group" : {
        "_id": "$Victim Age", "victimes": {"$sum": 1}
    }},
    { "$sort" : {
        "victimes": -1
    }}
])
    
list(victimWithEachAge)

# %%
# QCM 3
victimWithEachAgeByVictim = table.aggregate([
    {"$match": { "Weapon": "Drowning"}},
    { "$group" : {
        "_id": "$Victim Age", "victimes": {"$sum": 1}
    }},
    { "$sort" : {
        "victimes": -1
    }}
])
    
list(victimWithEachAgeByVictim)

# %%
# QCM 4
victimWithEachAgeByVictim = table.aggregate([
    {"$match": { "Weapon": "Fall"}},
    { "$group" : {
        "_id": "$State", "victimes": {"$sum": 1}
    }},
    { "$sort" : {
        "victimes": -1
    }}
])
    
list(victimWithEachAgeByVictim)

# %%
# QCM 5
victimWithEachAgeByVictim = table.aggregate([
    { "$group" : {
        "_id": "$State", "Moyenne": {"$avg": "$Victim Count"}
    }},
    { "$sort" : {
        "Moyenne": -1
    }}
])
    
list(victimWithEachAgeByVictim)
